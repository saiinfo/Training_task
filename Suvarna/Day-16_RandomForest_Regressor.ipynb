# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('ADANIPORTS.csv')

# %%
df.describe()
# Out:
#         Open Price   High Price    Low Price  Close Price          WAP  \
# count  2585.000000  2585.000000  2585.000000  2585.000000  2585.000000
# mean    284.795222   289.171277   279.368743   284.057408   284.345091
# std     132.298834   134.377313   129.807145   132.070991   132.151122
# min     107.750000   110.000000   105.150000   108.100000   108.470463
# 25%     153.150000   156.400000   150.300000   152.600000   153.490610
# 50%     293.300000   297.400000   287.550000   292.700000   292.862265
# 75%     369.150000   373.750000   363.550000   367.450000   368.521652
# max     887.650000   901.000000   859.250000   878.500000   877.215693
#
#        No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# count  2.585000e+03    2585.000000          2.585000e+03
# mean   3.940881e+05    4347.938878          1.252577e+08
# std    1.731142e+06    5643.755723          6.074498e+08
# min    4.675000e+03      99.000000          9.143080e+05
# 25%    1.138250e+05    1702.000000          2.538587e+07
# 50%    1.942290e+05    2754.000000          5.274390e+07
# 75%    3.476930e+05    4908.000000          9.870488e+07
# max    5.543831e+07  114761.000000          2.049315e+10
#
#        Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# count          2.584000e+03                2584.000000      2585.000000
# mean           1.806160e+05                  28.488378         9.802534
# std            1.572064e+06                  17.005879         7.692871
# min            2.370000e+03                   0.690000         1.300000
# 25%            2.460125e+04                  17.210000         5.400000
# 50%            4.421550e+04                  24.365000         7.800000
# 75%            8.923225e+04                  34.035000        11.500000
# max            5.525332e+07                  99.670000       109.200000
#
#        Spread Close-Open
# count        2585.000000
# mean           -0.737814
# std             7.048749
# min           -49.850000
# 25%            -3.850000
# 50%            -0.750000
# 75%             2.450000
# max            78.450000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2585 entries, 0 to 2584
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2585 non-null   object
#  1   Open Price                 2585 non-null   float64
#  2   High Price                 2585 non-null   float64
#  3   Low Price                  2585 non-null   float64
#  4   Close Price                2585 non-null   float64
#  5   WAP                        2585 non-null   float64
#  6   No.of Shares               2585 non-null   int64
#  7   No. of Trades              2585 non-null   int64
#  8   Total Turnover (Rs.)       2585 non-null   float64
#  9   Deliverable Quantity       2584 non-null   float64
#  10  % Deli. Qty to Traded Qty  2584 non-null   float64
#  11  Spread High-Low            2585 non-null   float64
#  12  Spread Close-Open          2585 non-null   float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 262.7+ KB

# %%
df.isnull().count()
# Out:
# Date                         2585
# Open Price                   2585
# High Price                   2585
# Low Price                    2585
# Close Price                  2585
# WAP                          2585
# No.of Shares                 2585
# No. of Trades                2585
# Total Turnover (Rs.)         2585
# Deliverable Quantity         2585
# % Deli. Qty to Traded Qty    2585
# Spread High-Low              2585
# Spread Close-Open            2585
# dtype: int64

# %%
df.head()
# Out:
#           Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0  9-June-2021      881.40       901.0     831.30       852.55  868.068924
# 1  8-June-2021      887.65       887.7     859.25       874.05  875.465358
# 2  7-June-2021      838.00       898.8     836.00       878.50  877.215693
# 3  4-June-2021      831.90       842.0     823.00       834.05  832.978840
# 4  3-June-2021      819.50       849.2     810.60       825.40  829.395433
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0       1417148          31843          1.230182e+09              191869.0
# 1        793172          16275          6.943946e+08               99676.0
# 2       2122651          53035          1.862023e+09              467381.0
# 3        847609          20716          7.060404e+08              198139.0
# 4       1490283          35855          1.236034e+09              319627.0
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                      13.54            69.70             -28.85
# 1                      12.57            28.45             -13.60
# 2                      22.02            62.80              40.50
# 3                      23.38            19.00               2.15
# 4                      21.45            38.60               5.90

# %%
df.sort_values(by=['Date'])
# Out:
#                   Date  Open Price  High Price  Low Price  Close Price  \
# 2522      1-April-2011      136.90      141.80     136.90       140.75
# 2024      1-April-2013      140.00      143.80     137.75       142.20
# 1773      1-April-2014      188.65      189.40     184.30       186.00
# 1530      1-April-2015      308.70      311.50     306.25       310.70
# 1283      1-April-2016      247.50      247.50     239.80       242.75
# ...                ...         ...         ...        ...          ...
# 1666  9-September-2014      301.80      301.80     293.95       295.10
# 1419  9-September-2015      322.20      327.45     320.50       323.95
# 1174  9-September-2016      275.00      275.50     270.15       271.45
# 434   9-September-2019      366.00      371.70     363.95       369.60
# 185   9-September-2020      345.60      346.25     335.45       344.10
#
#              WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 2522  140.311708        386849           4563            54279444.0
# 2024  141.380375        122679           2005            17344403.0
# 1773  186.721126        158631           2951            29619759.0
# 1530  309.297549         87552           2576            27079619.0
# 1283  243.300541        136687           2851            33256021.0
# ...          ...           ...            ...                   ...
# 1666  296.753273        300008           5676            89028356.0
# 1419  324.191741        172519           3379            55929235.0
# 1174  272.652845        445216           3558           121389409.0
# 434   368.091783         78261           2577            28807231.0
# 185   341.113467         86501           1595            29506656.0
#
#       Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 2522              187925.0                      48.58             4.90
# 2024               16067.0                      13.10             6.05
# 1773               43160.0                      27.21             5.10
# 1530               18682.0                      21.34             5.25
# 1283               36936.0                      27.02             7.70
# ...                    ...                        ...              ...
# 1666               79213.0                      26.40             7.85
# 1419               39486.0                      22.89             6.95
# 1174               45204.0                      10.15             5.35
# 434                19443.0                      24.84             7.75
# 185                 9255.0                      10.70            10.80
#
#       Spread Close-Open
# 2522               3.85
# 2024               2.20
# 1773              -2.65
# 1530               2.00
# 1283              -4.75
# ...                 ...
# 1666              -6.70
# 1419               1.75
# 1174              -3.55
# 434                3.60
# 185               -1.50
#
# [2585 rows x 13 columns]

# %%
print(df.head())
# Out:
#           Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0  9-June-2021      881.40       901.0     831.30       852.55  868.068924
# 1  8-June-2021      887.65       887.7     859.25       874.05  875.465358
# 2  7-June-2021      838.00       898.8     836.00       878.50  877.215693
# 3  4-June-2021      831.90       842.0     823.00       834.05  832.978840
# 4  3-June-2021      819.50       849.2     810.60       825.40  829.395433
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0       1417148          31843          1.230182e+09              191869.0
# 1        793172          16275          6.943946e+08               99676.0
# 2       2122651          53035          1.862023e+09              467381.0
# 3        847609          20716          7.060404e+08              198139.0
# 4       1490283          35855          1.236034e+09              319627.0
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                      13.54            69.70             -28.85
# 1                      12.57            28.45             -13.60
# 2                      22.02            62.80              40.50
# 3                      23.38            19.00               2.15
# 4                      21.45            38.60               5.90

# %%
plt.gca().invert_xaxis()
df['Close Price'].plot()
# Out:
# <Axes: >

# %%
X=df.reindex(columns=['Open Price','High Price','Low Price']).values
y=df.reindex(columns=['Close Price']).values

# %%
print(X,y)
# Out:
# [[881.4  901.   831.3 ]
#  [887.65 887.7  859.25]
#  [838.   898.8  836.  ]
#  ...
#  [150.   158.6  149.45]
#  [146.   150.   144.05]
#  [145.95 146.45 144.2 ]] [[852.55]
#  [874.05]
#  [878.5 ]
#  ...
#  [157.55]
#  [148.25]
#  [144.75]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)
rf_regressor.fit(X_train, y_train)
# Out:
# c:\Users\DC9890364443\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=42)

# %%
y_pred=rf_regressor.predict(X_test)
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

print(r2_score(y_test,y_pred))
# Out:
# Mean Squared Error: 12.307676719425798
# 0.999290974057438
