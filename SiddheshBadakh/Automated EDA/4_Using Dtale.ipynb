# %%
# !pip install dtale
# Out:
# ...
#      ---------------------------------------- 0.0/62.3 kB ? eta -:--:--
#      ---------------------------------------  61.4/62.3 kB 1.6 MB/s eta 0:00:01
#      ---------------------------------------- 62.3/62.3 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ------------ ------------------------- 204.8/642.7 kB 6.3 MB/s eta 0:00:01
#      -------------------------- ----------- 440.3/642.7 kB 5.5 MB/s eta 0:00:01
#      -------------------------------------- 642.7/642.7 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.5 MB 14.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import dtale

# %%
import seaborn as sns
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-O45E6J5J:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
