# %% [markdown]
# # Ridge Regression and Lasso

# %% [markdown]
# **Step 1: Import libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# **Step 2:Import Dataset**

# %%
data=pd.read_csv('Advertising.csv')
data.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
data.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %% [markdown]
# **Step 3:Feature Selection**

# %%
x=data[['TV','radio','sales']]
y=data[['sales']]

# %%
print(x)
# Out:
#         TV  radio  sales
# 0    230.1   37.8   22.1
# 1     44.5   39.3   10.4
# 2     17.2   45.9    9.3
# 3    151.5   41.3   18.5
# 4    180.8   10.8   12.9
# ..     ...    ...    ...
# 195   38.2    3.7    7.6
# 196   94.2    4.9    9.7
# 197  177.0    9.3   12.8
# 198  283.6   42.0   25.5
# 199  232.1    8.6   13.4
#
# [200 rows x 3 columns]

# %%
print(y)
# Out:
#      sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# ..     ...
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [200 rows x 1 columns]

# %% [markdown]
# **Step 4:Split the Data**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.10,random_state =2)

# %% [markdown]
# **Step 5:Train the Model**

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %% [markdown]
# **Step 6:Predict abd Evalute**

# %%
from sklearn.metrics import mean_squared_error

y_pred = model.predict(x_test)
mse=mean_squared_error(y_test,y_pred)

print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 5.8375706986354876e-30

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)

print(f"R-Squared: {r2}")
# Out:
# R-Squared: 1.0

# %% [markdown]
# ### Ridge regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

# %%
alpha = [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]

ridge = Ridge()

parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]}

ridge_regressor = GridSearchCV(ridge, parameters,scoring='neg_mean_squared_error', cv=5)

ridge_regressor.fit(Xs, y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20]},
#              scoring='neg_mean_squared_error')

# %%
ridge_regressor.best_params_
# Out:
# {'alpha': 20}

# %%
ridge_regressor.best_score_
# Out:
# -3.0726713383411433

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso

lasso = Lasso()

parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]}

lasso_regressor = GridSearchCV(lasso, parameters, scoring='neg_mean_squared_error', cv = 5)

lasso_regressor.fit(Xs, y)
# Out:
# c:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.972e+02, tolerance: 4.383e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.156e+02, tolerance: 4.218e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.700e+02, tolerance: 4.503e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.635e+02, tolerance: 4.199e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\asus\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.053e+02, tolerance: 4.348e-01
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20]},
#              scoring='neg_mean_squared_error')

# %%
lasso_regressor.best_params_
# Out:
# {'alpha': 1}

# %%
lasso_regressor.best_score_
# Out:
# -3.0414058967513684
