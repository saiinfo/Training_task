# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,color='red')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

X = df[['age']]
y = df['bought_insurance']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print(f'Accuracy Score: {accuracy}')
# Out:
# Accuracy Score: 0.8888888888888888

# %%
plt.scatter(X[y == 0], y[y == 0], color='blue', label='Not Bought Insurance')
plt.scatter(X[y == 1], y[y == 1], color='red', label='Bought Insurance')


x_values = np.linspace(X['age'].min(), X['age'].max(), 100)
decision_boundary = -model.intercept_ / model.coef_
plt.plot(x_values, model.predict(x_values.reshape(-1, 1)), color='green', label='Decision Boundary')

plt.xlabel('Age')
plt.ylabel('Bought Insurance (1) or Not (0)')
plt.title('Logistic Regression Decision Boundary and Data Points')
plt.legend()
plt.show()
